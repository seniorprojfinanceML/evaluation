# %%
from functions import Evaluation
from datetime import datetime
import matplotlib.pyplot as plt

# %%
table = "crypto_ind_one"
startDate = datetime(year=2024, month=2, day=25, hour=0, minute=0, second=0)
analysis = Evaluation(table=table, startDate = startDate, alias = "production", model = "Ridge")
# Out:
# analysis is done at 2024-04-06 15:16:56.169185
# querying
# processing
# requesting to the model server
# completed

# %%
analysis.plot()

# %%
analysis.plot_price()

# %%
report = analysis.classification_report()
print(report)
# Out:
# Classification report for Ridge model
#               precision    recall  f1-score   support
#
#            0       0.42      0.92      0.58     24008
#            1       0.64      0.10      0.17     33592
#
#     accuracy                           0.44     57600
#    macro avg       0.53      0.51      0.38     57600
# weighted avg       0.55      0.44      0.34     57600

# %%
analysis.mse()
# Out:
# 0.0014905780051900936
