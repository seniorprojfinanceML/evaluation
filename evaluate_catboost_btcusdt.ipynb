# %%
from functions import Evaluation
from datetime import datetime
import matplotlib.pyplot as plt

# %%
table = "crypto_ind_one"
startDate = datetime(year=2024, month=2, day=25, hour=0, minute=0, second=0)
analysis = Evaluation(table=table, startDate = startDate, alias = "production", model = "CBR")
# Out:
# analysis is done at 2024-04-06 13:12:00.441963
# querying
# processing
# requesting to the model server
# completed

# %%
analysis.plot()

# %%
analysis.plot_price()

# %%
report = analysis.classification_report()
print(report)
# Out:
# Classification report for CBR model
#               precision    recall  f1-score   support
#
#            0       0.41      0.96      0.58     24008
#            1       0.29      0.01      0.02     33592
#
#     accuracy                           0.41     57600
#    macro avg       0.35      0.49      0.30     57600
# weighted avg       0.34      0.41      0.25     57600

# %%
analysis.mse()
# Out:
# 0.0018060785196488596
