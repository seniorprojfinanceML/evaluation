# %%
from functions import Evaluation
from datetime import datetime
import matplotlib.pyplot as plt

# %%
table = "crypto_ind_one"
startDate = datetime(year=2024, month=2, day=25, hour=0, minute=0, second=0)
analysis = Evaluation(table=table, startDate = startDate, alias = "production", model = "Huber")
# Out:
# analysis is done at 2024-04-06 15:17:02.811140
# querying
# processing
# requesting to the model server
# completed

# %%
analysis.plot()

# %%
analysis.plot_price()

# %%
report = analysis.classification_report()
print(report)
# Out:
# Classification report for Huber model
#               precision    recall  f1-score   support
#
#            0       0.41      0.97      0.58     24008
#            1       0.44      0.01      0.03     33592
#
#     accuracy                           0.41     57600
#    macro avg       0.43      0.49      0.30     57600
# weighted avg       0.43      0.41      0.26     57600

# %%
analysis.mse()
# Out:
# 0.0015030517421374618
